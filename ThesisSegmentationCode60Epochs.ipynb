# %%
# Import packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import zipfile
import cv2
from skimage import io
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
import tensorflow as tf
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.layers import *
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import Input
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from IPython.display import display
from tensorflow.keras import backend as K
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.model_selection import train_test_split
from skimage.color import rgb2gray
import os
import glob
import random
plt.style.use("ggplot")
from tqdm import tqdm_notebook, tnrange
from glob import glob
from itertools import chain
from google.colab import files #library to upload files to colab notebook
# %matplotlib inline

# %%
# Mount the Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Navigate to the dataset folder
# %cd /content/drive/My Drive/Colab Notebooks/Healthcare AI Datasets/Brain_MRI
# Out:
# /content/drive/My Drive/Colab Notebooks/Healthcare AI Datasets/Brain_MRI

# %%
#Set Parameters
im_width = 256
im_height = 256

# %%
train_files = []
mask_files = glob('*/*_mask*')

for i in mask_files:
    train_files.append(i.replace('_mask',''))

print(train_files[:10])
print(mask_files[:10])
# Out:
# ['TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_10.tif', 'TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_11.tif', 'TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_13.tif', 'TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_14.tif', 'TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_12.tif', 'TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_18.tif', 'TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_15.tif', 'TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_16.tif', 'TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_17.tif', 'TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_20.tif']
# ['TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_10_mask.tif', 'TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_11_mask.tif', 'TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_13_mask.tif', 'TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_14_mask.tif', 'TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_12_mask.tif', 'TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_18_mask.tif', 'TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_15_mask.tif', 'TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_16_mask.tif', 'TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_17_mask.tif', 'TCGA_CS_4941_19960909/TCGA_CS_4941_19960909_20_mask.tif']

# %%
#Lets plot some samples
rows,cols=3,3
fig=plt.figure(figsize=(10,10))
for i in range(1,rows*cols+1):
    fig.add_subplot(rows,cols,i)
    img_path=train_files[i]
    msk_path=mask_files[i]
    img=cv2.imread(img_path)
    img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
    msk=cv2.imread(msk_path)
    plt.imshow(img)
    plt.imshow(msk,alpha=0.4)
plt.show()

# %%
df = pd.DataFrame(data={"filename": train_files, 'mask' : mask_files})
df_train, df_test = train_test_split(df,test_size = 0.1)
df_train, df_val = train_test_split(df_train,test_size = 0.2)
print(df_train.values.shape)
print(df_val.values.shape)
print(df_test.values.shape)
# Out:
# (2828, 2)
# (708, 2)
# (393, 2)

# %%
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):
    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "filename",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %%
smooth=100

def dice_coef(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)
    And=K.sum(y_truef* y_predf)
    return((2* And + smooth) / (K.sum(y_truef) + K.sum(y_predf) + smooth))

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

def jac_distance(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)

    return - iou(y_true, y_pred)

# %%
def unet(input_size=(256,256,3)):
    inputs = Input(input_size)
    
    conv1 = Conv2D(64, (3, 3), padding='same')(inputs)
    bn1 = Activation('relu')(conv1)
    conv1 = Conv2D(64, (3, 3), padding='same')(bn1)
    bn1 = BatchNormalization(axis=3)(conv1)
    bn1 = Activation('relu')(bn1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(bn1)

    conv2 = Conv2D(128, (3, 3), padding='same')(pool1)
    bn2 = Activation('relu')(conv2)
    conv2 = Conv2D(128, (3, 3), padding='same')(bn2)
    bn2 = BatchNormalization(axis=3)(conv2)
    bn2 = Activation('relu')(bn2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(bn2)

    conv3 = Conv2D(256, (3, 3), padding='same')(pool2)
    bn3 = Activation('relu')(conv3)
    conv3 = Conv2D(256, (3, 3), padding='same')(bn3)
    bn3 = BatchNormalization(axis=3)(conv3)
    bn3 = Activation('relu')(bn3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(bn3)

    conv4 = Conv2D(512, (3, 3), padding='same')(pool3)
    bn4 = Activation('relu')(conv4)
    conv4 = Conv2D(512, (3, 3), padding='same')(bn4)
    bn4 = BatchNormalization(axis=3)(conv4)
    bn4 = Activation('relu')(bn4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(bn4)

    conv5 = Conv2D(1024, (3, 3), padding='same')(pool4)
    bn5 = Activation('relu')(conv5)
    conv5 = Conv2D(1024, (3, 3), padding='same')(bn5)
    bn5 = BatchNormalization(axis=3)(conv5)
    bn5 = Activation('relu')(bn5)

    up6 = concatenate([Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(bn5), conv4], axis=3)
    conv6 = Conv2D(512, (3, 3), padding='same')(up6)
    bn6 = Activation('relu')(conv6)
    conv6 = Conv2D(512, (3, 3), padding='same')(bn6)
    bn6 = BatchNormalization(axis=3)(conv6)
    bn6 = Activation('relu')(bn6)

    up7 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(bn6), conv3], axis=3)
    conv7 = Conv2D(256, (3, 3), padding='same')(up7)
    bn7 = Activation('relu')(conv7)
    conv7 = Conv2D(256, (3, 3), padding='same')(bn7)
    bn7 = BatchNormalization(axis=3)(conv7)
    bn7 = Activation('relu')(bn7)

    up8 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(bn7), conv2], axis=3)
    conv8 = Conv2D(128, (3, 3), padding='same')(up8)
    bn8 = Activation('relu')(conv8)
    conv8 = Conv2D(128, (3, 3), padding='same')(bn8)
    bn8 = BatchNormalization(axis=3)(conv8)
    bn8 = Activation('relu')(bn8)

    up9 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(bn8), conv1], axis=3)
    conv9 = Conv2D(64, (3, 3), padding='same')(up9)
    bn9 = Activation('relu')(conv9)
    conv9 = Conv2D(64, (3, 3), padding='same')(bn9)
    bn9 = BatchNormalization(axis=3)(conv9)
    bn9 = Activation('relu')(bn9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(bn9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
model = unet()
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_57 (Conv2D)             (None, 256, 256, 64  1792        ['input_4[0][0]']
#                                 )
#
#  activation_54 (Activation)     (None, 256, 256, 64  0           ['conv2d_57[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 256, 256, 64  36928       ['activation_54[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 256, 256, 64  256        ['conv2d_58[0][0]']
#  ormalization)                  )
#
#  activation_55 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_27[0][0]']
#                                 )
#
#  max_pooling2d_12 (MaxPooling2D  (None, 128, 128, 64  0          ['activation_55[0][0]']
#  )                              )
#
#  conv2d_59 (Conv2D)             (None, 128, 128, 12  73856       ['max_pooling2d_12[0][0]']
#                                 8)
#
#  activation_56 (Activation)     (None, 128, 128, 12  0           ['conv2d_59[0][0]']
#                                 8)
#
#  conv2d_60 (Conv2D)             (None, 128, 128, 12  147584      ['activation_56[0][0]']
#                                 8)
#
#  batch_normalization_28 (BatchN  (None, 128, 128, 12  512        ['conv2d_60[0][0]']
#  ormalization)                  8)
#
#  activation_57 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_28[0][0]']
#                                 8)
#
#  max_pooling2d_13 (MaxPooling2D  (None, 64, 64, 128)  0          ['activation_57[0][0]']
#  )
#
#  conv2d_61 (Conv2D)             (None, 64, 64, 256)  295168      ['max_pooling2d_13[0][0]']
#
#  activation_58 (Activation)     (None, 64, 64, 256)  0           ['conv2d_61[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_58[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_62[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 32, 32, 256)  0          ['activation_59[0][0]']
#  )
#
#  conv2d_63 (Conv2D)             (None, 32, 32, 512)  1180160     ['max_pooling2d_14[0][0]']
#
#  activation_60 (Activation)     (None, 32, 32, 512)  0           ['conv2d_63[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_60[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_64[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_30[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 16, 16, 512)  0          ['activation_61[0][0]']
#  )
#
#  conv2d_65 (Conv2D)             (None, 16, 16, 1024  4719616     ['max_pooling2d_15[0][0]']
#                                 )
#
#  activation_62 (Activation)     (None, 16, 16, 1024  0           ['conv2d_65[0][0]']
#                                 )
#
#  conv2d_66 (Conv2D)             (None, 16, 16, 1024  9438208     ['activation_62[0][0]']
#                                 )
#
#  batch_normalization_31 (BatchN  (None, 16, 16, 1024  4096       ['conv2d_66[0][0]']
#  ormalization)                  )
#
#  activation_63 (Activation)     (None, 16, 16, 1024  0           ['batch_normalization_31[0][0]']
#                                 )
#
#  conv2d_transpose_12 (Conv2DTra  (None, 32, 32, 512)  2097664    ['activation_63[0][0]']
#  nspose)
#
#  concatenate_12 (Concatenate)   (None, 32, 32, 1024  0           ['conv2d_transpose_12[0][0]',
#                                 )                                 'conv2d_64[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate_12[0][0]']
#
#  activation_64 (Activation)     (None, 32, 32, 512)  0           ['conv2d_67[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 32, 32, 512)  2359808     ['activation_64[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 32, 32, 512)  2048       ['conv2d_68[0][0]']
#  ormalization)
#
#  activation_65 (Activation)     (None, 32, 32, 512)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_transpose_13 (Conv2DTra  (None, 64, 64, 256)  524544     ['activation_65[0][0]']
#  nspose)
#
#  concatenate_13 (Concatenate)   (None, 64, 64, 512)  0           ['conv2d_transpose_13[0][0]',
#                                                                   'conv2d_62[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_13[0][0]']
#
#  activation_66 (Activation)     (None, 64, 64, 256)  0           ['conv2d_69[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_66[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 64, 64, 256)  1024       ['conv2d_70[0][0]']
#  ormalization)
#
#  activation_67 (Activation)     (None, 64, 64, 256)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_transpose_14 (Conv2DTra  (None, 128, 128, 12  131200     ['activation_67[0][0]']
#  nspose)                        8)
#
#  concatenate_14 (Concatenate)   (None, 128, 128, 25  0           ['conv2d_transpose_14[0][0]',
#                                 6)                                'conv2d_60[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_14[0][0]']
#                                 8)
#
#  activation_68 (Activation)     (None, 128, 128, 12  0           ['conv2d_71[0][0]']
#                                 8)
#
#  conv2d_72 (Conv2D)             (None, 128, 128, 12  147584      ['activation_68[0][0]']
#                                 8)
#
#  batch_normalization_34 (BatchN  (None, 128, 128, 12  512        ['conv2d_72[0][0]']
#  ormalization)                  8)
#
#  activation_69 (Activation)     (None, 128, 128, 12  0           ['batch_normalization_34[0][0]']
#                                 8)
#
#  conv2d_transpose_15 (Conv2DTra  (None, 256, 256, 64  32832      ['activation_69[0][0]']
#  nspose)                        )
#
#  concatenate_15 (Concatenate)   (None, 256, 256, 12  0           ['conv2d_transpose_15[0][0]',
#                                 8)                                'conv2d_58[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_15[0][0]']
#                                 )
#
#  activation_70 (Activation)     (None, 256, 256, 64  0           ['conv2d_73[0][0]']
#                                 )
#
#  conv2d_74 (Conv2D)             (None, 256, 256, 64  36928       ['activation_70[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 256, 256, 64  256        ['conv2d_74[0][0]']
#  ormalization)                  )
#
#  activation_71 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_35[0][0]']
#                                 )
#
#  conv2d_75 (Conv2D)             (None, 256, 256, 1)  65          ['activation_71[0][0]']
#
# ==================================================================================================
# Total params: 31,043,521
# Trainable params: 31,037,633
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %%
# Set the hyperparameters and train the model
EPOCHS = 60
BATCH_SIZE = 32
learning_rate = 1e-4

# %%
train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')
train_gen = train_generator(df_train, BATCH_SIZE,
                                train_generator_args,
                                target_size=(im_height, im_width))
    
test_gener = train_generator(df_val, BATCH_SIZE,
                                dict(),
                                target_size=(im_height, im_width))
    
model = unet(input_size=(im_height, im_width, 3))



decay_rate = learning_rate / EPOCHS
opt = Adam(lr=learning_rate, beta_1=0.9, beta_2=0.999, epsilon=None, decay=decay_rate, amsgrad=False)
model.compile(optimizer=opt, loss=dice_coef_loss, metrics=["binary_accuracy", iou, dice_coef])

callbacks = [ModelCheckpoint('unet_brain_mri_seg.hdf5', verbose=1, save_best_only=True)]

history = model.fit(train_gen,
                    steps_per_epoch=len(df_train) / BATCH_SIZE, 
                    epochs=EPOCHS, 
                    callbacks=callbacks,
                    validation_data = test_gener,
                    validation_steps=len(df_val) / BATCH_SIZE)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Found 2828 validated image filenames.
# Found 2828 validated image filenames.
# Epoch 1/60
# 89/88 [==============================] - ETA: 0s - loss: -0.1054 - binary_accuracy: 0.9208 - iou: 0.0570 - dice_coef: 0.1058Found 708 validated image filenames.
# Found 708 validated image filenames.
#
# Epoch 1: val_loss improved from inf to -0.02581, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 102s 1s/step - loss: -0.1054 - binary_accuracy: 0.9208 - iou: 0.0570 - dice_coef: 0.1058 - val_loss: -0.0258 - val_binary_accuracy: 0.9890 - val_iou: 0.0133 - val_dice_coef: 0.0260
# Epoch 2/60
# 89/88 [==============================] - ETA: 0s - loss: -0.1777 - binary_accuracy: 0.9830 - iou: 0.0990 - dice_coef: 0.1777
# Epoch 2: val_loss did not improve from -0.02581
# 88/88 [==============================] - 95s 1s/step - loss: -0.1777 - binary_accuracy: 0.9830 - iou: 0.0990 - dice_coef: 0.1777 - val_loss: -0.0218 - val_binary_accuracy: 0.9889 - val_iou: 0.0110 - val_dice_coef: 0.0214
# Epoch 3/60
# 89/88 [==============================] - ETA: 0s - loss: -0.2251 - binary_accuracy: 0.9893 - iou: 0.1287 - dice_coef: 0.2249
# Epoch 3: val_loss improved from -0.02581 to -0.07844, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 99s 1s/step - loss: -0.2251 - binary_accuracy: 0.9893 - iou: 0.1287 - dice_coef: 0.2249 - val_loss: -0.0784 - val_binary_accuracy: 0.9908 - val_iou: 0.0402 - val_dice_coef: 0.0757
# Epoch 4/60
# 89/88 [==============================] - ETA: 0s - loss: -0.2748 - binary_accuracy: 0.9907 - iou: 0.1618 - dice_coef: 0.2748
# Epoch 4: val_loss improved from -0.07844 to -0.10611, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 100s 1s/step - loss: -0.2748 - binary_accuracy: 0.9907 - iou: 0.1618 - dice_coef: 0.2748 - val_loss: -0.1061 - val_binary_accuracy: 0.9878 - val_iou: 0.0551 - val_dice_coef: 0.1025
# Epoch 5/60
# 89/88 [==============================] - ETA: 0s - loss: -0.3367 - binary_accuracy: 0.9930 - iou: 0.2062 - dice_coef: 0.3377
# Epoch 5: val_loss improved from -0.10611 to -0.30037, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 101s 1s/step - loss: -0.3367 - binary_accuracy: 0.9930 - iou: 0.2062 - dice_coef: 0.3377 - val_loss: -0.3004 - val_binary_accuracy: 0.9928 - val_iou: 0.1789 - val_dice_coef: 0.2995
# Epoch 6/60
# 89/88 [==============================] - ETA: 0s - loss: -0.3909 - binary_accuracy: 0.9938 - iou: 0.2480 - dice_coef: 0.3912
# Epoch 6: val_loss improved from -0.30037 to -0.43578, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 101s 1s/step - loss: -0.3909 - binary_accuracy: 0.9938 - iou: 0.2480 - dice_coef: 0.3912 - val_loss: -0.4358 - val_binary_accuracy: 0.9942 - val_iou: 0.2776 - val_dice_coef: 0.4278
# Epoch 7/60
# 89/88 [==============================] - ETA: 0s - loss: -0.4668 - binary_accuracy: 0.9949 - iou: 0.3093 - dice_coef: 0.4672
# Epoch 7: val_loss improved from -0.43578 to -0.55428, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 101s 1s/step - loss: -0.4668 - binary_accuracy: 0.9949 - iou: 0.3093 - dice_coef: 0.4672 - val_loss: -0.5543 - val_binary_accuracy: 0.9946 - val_iou: 0.3793 - val_dice_coef: 0.5442
# Epoch 8/60
# 89/88 [==============================] - ETA: 0s - loss: -0.5178 - binary_accuracy: 0.9952 - iou: 0.3560 - dice_coef: 0.5184
# Epoch 8: val_loss improved from -0.55428 to -0.55893, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] -
60
# 89/88 [==============================] - ETA: 0s - loss: -0.8669 - binary_accuracy: 0.9978 - iou: 0.7694 - dice_coef: 0.8662
# Epoch 30: val_loss did not improve from -0.87197
# 88/88 [==============================] - 95s 1s/step - loss: -0.8669 - binary_accuracy: 0.9978 - iou: 0.7694 - dice_coef: 0.8662 - val_loss: -0.8699 - val_binary_accuracy: 0.9976 - val_iou: 0.7651 - val_dice_coef: 0.8651
# Epoch 31/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8657 - binary_accuracy: 0.9979 - iou: 0.7644 - dice_coef: 0.8621
# Epoch 31: val_loss did not improve from -0.87197
# 88/88 [==============================] - 94s 1s/step - loss: -0.8657 - binary_accuracy: 0.9979 - iou: 0.7644 - dice_coef: 0.8621 - val_loss: -0.8689 - val_binary_accuracy: 0.9972 - val_iou: 0.7703 - val_dice_coef: 0.8688
# Epoch 32/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8420 - binary_accuracy: 0.9973 - iou: 0.7325 - dice_coef: 0.8406
# Epoch 32: val_loss did not improve from -0.87197
# 88/88 [==============================] - 95s 1s/step - loss: -0.8420 - binary_accuracy: 0.9973 - iou: 0.7325 - dice_coef: 0.8406 - val_loss: -0.8536 - val_binary_accuracy: 0.9970 - val_iou: 0.7286 - val_dice_coef: 0.8348
# Epoch 33/60
# 89/88 [==============================] - ETA: 0s - loss: -0.0567 - binary_accuracy: 0.9600 - iou: 0.0303 - dice_coef: 0.0567
# Epoch 33: val_loss did not improve from -0.87197
# 88/88 [==============================] - 94s 1s/step - loss: -0.0567 - binary_accuracy: 0.9600 - iou: 0.0303 - dice_coef: 0.0567 - val_loss: -0.2056 - val_binary_accuracy: 0.9157 - val_iou: 0.1183 - val_dice_coef: 0.2095
# Epoch 34/60
# 89/88 [==============================] - ETA: 0s - loss: -0.7574 - binary_accuracy: 0.9944 - iou: 0.6294 - dice_coef: 0.7583
# Epoch 34: val_loss did not improve from -0.87197
# 88/88 [==============================] - 95s 1s/step - loss: -0.7574 - binary_accuracy: 0.9944 - iou: 0.6294 - dice_coef: 0.7583 - val_loss: -0.8317 - val_binary_accuracy: 0.9970 - val_iou: 0.7144 - val_dice_coef: 0.8309
# Epoch 35/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8530 - binary_accuracy: 0.9974 - iou: 0.7478 - dice_coef: 0.8528
# Epoch 35: val_loss did not improve from -0.87197
# 88/88 [==============================] - 95s 1s/step - loss: -0.8530 - binary_accuracy: 0.9974 - iou: 0.7478 - dice_coef: 0.8528 - val_loss: -0.8566 - val_binary_accuracy: 0.9968 - val_iou: 0.7460 - val_dice_coef: 0.8530
# Epoch 36/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8679 - binary_accuracy: 0.9976 - iou: 0.7728 - dice_coef: 0.8679
# Epoch 36: val_loss improved from -0.87197 to -0.87997, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 100s 1s/step - loss: -0.8679 - binary_accuracy: 0.9976 - iou: 0.7728 - dice_coef: 0.8679 - val_loss: -0.8800 - val_binary_accuracy: 0.9976 - val_iou: 0.7910 - val_dice_coef: 0.8824
# Epoch 37/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8804 - binary_accuracy: 0.9979 - iou: 0.7889 - dice_coef: 0.8797
# Epoch 37: val_loss did not improve from -0.87997
# 88/88 [==============================] - 96s 1s/step - loss: -0.8804 - binary_accuracy: 0.9979 - iou: 0.7889 - dice_coef: 0.8797 - val_loss: -0.8747 - val_binary_accuracy: 0.9974 - val_iou: 0.7819 - val_dice_coef: 0.8755
# Epoch 38/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8789 - binary_accuracy: 0.9979 - iou: 0.7881 - dice_coef: 0.8787
# Epoch 38: val_loss improved from -0.87997 to -0.88313, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 100s 1s/step - loss: -0.8789 - binary_accuracy: 0.9979 - iou: 0.7881 - dice_coef: 0.8787 - val_loss: -0.8831 - val_binary_accuracy: 0.9976 - val_iou: 0.7674 - val_dice_coef: 0.8528
# Epoch 39/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8703 - binary_accuracy: 0.9977 - iou: 0.7778 - dice_coef: 0.8707
# Epoch 39: val_loss did not improve from -0.88313
# 88/88 [==============================] - 96s 1s/step - loss: -0.8703 - binary_accuracy: 0.9977 - iou: 0.7778 - dice_coef: 0.8707 - val_loss: -0.8738 - val_binary_accuracy: 0.9976 - val_iou: 0.7819 - val_dice_coef: 0.8758
# Epoch 40/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8709 - binary_accuracy: 0.9977 - iou: 0.7781 - dice_coef: 0.8709
# Epoch 40: val_loss did not improve from -0.88313
# 88/88 [==============================] - 96s 1s/step - loss: -0.8709 - binary_accuracy: 0.9977 - iou: 0.7781 - dice_coef: 0.8709 - val_loss: -0.8542 - val_binary_accuracy: 0.9973 - val_iou: 0.7424 - val_dice_coef: 0.8501
# Epoch 41/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8712 - binary_accuracy: 0.9976 - iou: 0.7760 - dice_coef: 0.8680
# Epoch 41: val_loss did not improve from -0.88313
# 88/88 [==============================] - 95s 1s/step - loss: -0.8712 - binary_accuracy: 0.9976 - iou: 0.7760 - dice_coef: 0.8680 - val_loss: -0.8784 - val_binary_accuracy: 0.9972 - val_iou: 0.7909 - val_dice_coef: 0.8819
# Epoch 42/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8730 - binary_accuracy: 0.9977 - iou: 0.7771 - dice_coef: 0.8726
# Epoch 42: val_loss improved from -0.88313 to -0.88553, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 101s 1s/step - loss: -0.8730 - binary_accuracy: 0.9977 - iou: 0.7771 - dice_coef: 0.8726 - val_loss: -0.8855 - val_binary_accuracy: 0.9977 - val_iou: 0.8002 - val_dice_coef: 0.8876
# Epoch 43/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8672 - binary_accuracy: 0.9977 - iou: 0.7718 - dice_coef: 0.8677
# Epoch 43: val_loss improved from -0.88553 to -0.88998, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 101s 1s/step - loss: -0.8672 - binary_accuracy: 0.9977 - iou: 0.7718 - dice_coef: 0.8677 - val_loss: -0.8900 - val_binary_accuracy: 0.9977 - val_iou: 0.8029 - val_dice_coef: 0.8897
# Epoch 44/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8875 - binary_accuracy: 0.9981 - iou: 0.8061 - dice_coef: 0.8877
# Epoch 44: val_loss improved from -0.88998 to -0.89125, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 105s 1s/step - loss: -0.8875 - binary_accuracy: 0.9981 - iou: 0.8061 - dice_coef: 0.8877 - val_loss: -0.8913 - val_binary_accuracy: 0.9978 - val_iou: 0.7999 - val_dice_coef: 0.8869
# Epoch 45/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8953 - binary_accuracy: 0.9981 - iou: 0.8125 - dice_coef: 0.8955
# Epoch 45: val_loss did not improve from -0.89125
# 88/88 [==============================] - 95s 1s/step - loss: -0.8953 - binary_accuracy: 0.9981 - iou: 0.8125 - dice_coef: 0.8955 - val_loss: -0.8885 - val_binary_accuracy: 0.9977 - val_iou: 0.7985 - val_dice_coef: 0.8862
# Epoch 46/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8917 - binary_accuracy: 0.9980 - iou: 0.8078 - dice_coef: 0.8917
# Epoch 46: val_loss improved from -0.89125 to -0.89298, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 99s 1s/step - loss: -0.8917 - binary_accuracy: 0.9980 - iou: 0.8078 - dice_coef: 0.8917 - val_loss: -0.8930 - val_binary_accuracy: 0.9977 - val_iou: 0.8098 - val_dice_coef: 0.8903
# Epoch 47/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8895 - binary_accuracy: 0.9980 - iou: 0.8051 - dice_coef: 0.8896
# Epoch 47: val_loss improved from -0.89298 to -0.89322, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 102s 1s/step - loss: -0.8895 - binary_accuracy: 0.9980 - iou: 0.8051 - dice_coef: 0.8896 - val_loss: -0.8932 - val_binary_accuracy: 0.9977 - val_iou: 0.8061 - val_dice_coef: 0.8906
# Epoch 48/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8839 - binary_accuracy: 0.9979 - iou: 0.7974 - dice_coef: 0.8843
# Epoch 48: val_loss did not improve from -0.89322
# 88/88 [==============================] - 98s 1s/step - loss: -0.8839 - binary_accuracy: 0.9979 - iou: 0.7974 - dice_coef: 0.8843 - val_loss: -0.8822 - val_binary_accuracy: 0.9974 - val_iou: 0.7945 - val_dice_coef: 0.8840
# Epoch 49/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8921 - binary_accuracy: 0.9979 - iou: 0.8113 - dice_coef: 0.8922
# Epoch 49: val_loss did not improve from -0.89322
# 88/88 [==============================] - 94s 1s/step - loss: -0.8921 - binary_accuracy: 0.9979 - iou: 0.8113 - dice_coef: 0.8922 - val_loss: -0.8842 - val_binary_accuracy: 0.9975 - val_iou: 0.7878 - val_dice_coef: 0.8794
# Epoch 50/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8770 - binary_accuracy: 0.9978 - iou: 0.7857 - dice_coef: 0.8757
# Epoch 50: val_loss did not improve from -0.89322
# 88/88 [==============================] - 94s 1s/step - loss: -0.8770 - binary_accuracy: 0.9978 - iou: 0.7857 - dice_coef: 0.8757 - val_loss: -0.8700 - val_binary_accuracy: 0.9973 - val_iou: 0.7714 - val_dice_coef: 0.8693
# Epoch 51/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8686 - binary_accuracy: 0.9976 - iou: 0.7731 - dice_coef: 0.8686
# Epoch 51: val_loss did not improve from -0.89322
# 88/88 [==============================] - 95s 1s/step - loss: -0.8686 - binary_accuracy: 0.9976 - iou: 0.7731 - dice_coef: 0.8686 - val_loss: -0.8683 - val_binary_accuracy: 0.9973 - val_iou: 0.7698 - val_dice_coef: 0.8677
# Epoch 52/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8825 - binary_accuracy: 0.9979 - iou: 0.7955 - dice_coef: 0.8827
# Epoch 52: val_loss did not improve from -0.89322
# 88/88 [==============================] - 95s 1s/step - loss: -0.8825 - binary_accuracy: 0.9979 - iou: 0.7955 - dice_coef: 0.8827 - val_loss: -0.8906 - val_binary_accuracy: 0.9976 - val_iou: 0.8028 - val_dice_coef: 0.8891
# Epoch 53/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8924 - binary_accuracy: 0.9980 - iou: 0.8115 - dice_coef: 0.8925
# Epoch 53: val_loss did not improve from -0.89322
# 88/88 [==============================] - 93s 1s/step - loss: -0.8924 - binary_accuracy: 0.9980 - iou: 0.8115 - dice_coef: 0.8925 - val_loss: -0.8930 - val_binary_accuracy: 0.9978 - val_iou: 0.8120 - val_dice_coef: 0.8927
# Epoch 54/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8969 - binary_accuracy: 0.9980 - iou: 0.8181 - dice_coef: 0.8969
# Epoch 54: val_loss improved from -0.89322 to -0.90058, saving model to unet_brain_mri_seg.hdf5
# 88/88 [==============================] - 99s 1s/step - loss: -0.8969 - binary_accuracy: 0.9980 - iou: 0.8181 - dice_coef: 0.8969 - val_loss: -0.9006 - val_binary_accuracy: 0.9978 - val_iou: 0.8238 - val_dice_coef: 0.9026
# Epoch 55/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8874 - binary_accuracy: 0.9979 - iou: 0.8037 - dice_coef: 0.8877
# Epoch 55: val_loss did not improve from -0.90058
# 88/88 [==============================] - 96s 1s/step - loss: -0.8874 - binary_accuracy: 0.9979 - iou: 0.8037 - dice_coef: 0.8877 - val_loss: -0.8873 - val_binary_accuracy: 0.9977 - val_iou: 0.7991 - val_dice_coef: 0.8874
# Epoch 56/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8997 - binary_accuracy: 0.9981 - iou: 0.8227 - dice_coef: 0.8997
# Epoch 56: val_loss did not improve from -0.90058
# 88/88 [==============================] - 95s 1s/step - loss: -0.8997 - binary_accuracy: 0.9981 - iou: 0.8227 - dice_coef: 0.8997 - val_loss: -0.8971 - val_binary_accuracy: 0.9977 - val_iou: 0.8107 - val_dice_coef: 0.8932
# Epoch 57/60
# 89/88 [==============================] - ETA: 0s - loss: -0.9008 - binary_accuracy: 0.9982 - iou: 0.8240 - dice_coef: 0.9007
# Epoch 57: val_loss did not improve from -0.90058
# 88/88 [==============================] - 93s 1s/step - loss: -0.9008 - binary_accuracy: 0.9982 - iou: 0.8240 - dice_coef: 0.9007 - val_loss: -0.8865 - val_binary_accuracy: 0.9976 - val_iou: 0.8019 - val_dice_coef: 0.8887
# Epoch 58/60
# 89/88 [==============================] - ETA: 0s - loss: -0.9011 - binary_accuracy: 0.9981 - iou: 0.8240 - dice_coef: 0.9010
# Epoch 58: val_loss did not improve from -0.90058
# 88/88 [==============================] - 95s 1s/step - loss: -0.9011 - binary_accuracy: 0.9981 - iou: 0.8240 - dice_coef: 0.9010 - val_loss: -0.8993 - val_binary_accuracy: 0.9977 - val_iou: 0.8128 - val_dice_coef: 0.8952
# Epoch 59/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8870 - binary_accuracy: 0.9980 - iou: 0.8040 - dice_coef: 0.8874
# Epoch 59: val_loss did not improve from -0.90058
# 88/88 [==============================] - 96s 1s/step - loss: -0.8870 - binary_accuracy: 0.9980 - iou: 0.8040 - dice_coef: 0.8874 - val_loss: -0.8785 - val_binary_accuracy: 0.9976 - val_iou: 0.7907 - val_dice_coef: 0.8798
# Epoch 60/60
# 89/88 [==============================] - ETA: 0s - loss: -0.8997 - binary_accuracy: 0.9981 - iou: 0.8202 - dice_coef: 0.8978
# Epoch 60: val_loss did not improve from -0.90058
# 88/88 [==============================] - 94s 1s/step - loss: -0.8997 - binary_accuracy: 0.9981 - iou: 0.8202 - dice_coef: 0.8978 - val_loss: -0.8966 - val_binary_accuracy: 0.9976 - val_iou: 0.8151 - val_dice_coef: 0.8972

# %%
a = history.history

list_traindice = a['dice_coef']
list_testdice = a['val_dice_coef']

list_trainjaccard = a['iou']
list_testjaccard = a['val_iou']

list_trainloss = a['loss']
list_testloss = a['val_loss']
plt.figure(1)
plt.plot(list_testloss, 'b-')
plt.plot(list_trainloss,'r-')
plt.xlabel('iteration')
plt.ylabel('loss')
plt.title('loss graph', fontsize = 15)
plt.figure(2)
plt.plot(list_traindice, 'r-')
plt.plot(list_testdice, 'b-')
plt.xlabel('iteration')
plt.ylabel('accuracy')
plt.title('accuracy graph', fontsize = 15)
plt.show()

# %%
plt.figure(figsize=(8,15))
plt.subplot(3,1,1)
plt.plot(a['loss'], 'b-', label='train_loss')
plt.plot(a['val_loss'], 'r-', label='val_loss')
plt.legend(loc='best')
plt.title('Loss')

plt.subplot(3,1,2)
plt.plot(a['iou'], 'b-', label='train_iou')
plt.plot(a['val_iou'], 'r-', label='val_iou')
plt.legend(loc='best')
plt.title('IoU')

plt.subplot(3,1,3)
plt.plot(a['dice_coef'], 'b-', label='train_dice_coef')
plt.plot(a['val_dice_coef'], 'r-', label='val_dice_coef')
plt.legend(loc='best')
plt.title('Dice Coef')
# Out:
# Text(0.5, 1.0, 'Dice Coef')

# %%
model = load_model('unet_brain_mri_seg.hdf5', custom_objects={'dice_coef_loss': dice_coef_loss, 'iou': iou, 'dice_coef': dice_coef})

# %%
# Validate on the test dataset
test_gen = train_generator(df_test, BATCH_SIZE,
                                dict(),
                                target_size=(im_height, im_width))
results = model.evaluate(test_gen, steps=len(df_test) / BATCH_SIZE)
print("Test lost: ",results[0])
print("Test IOU: ",results[1])
print("Test Dice Coefficent: ",results[2])
# Out:
# Found 393 validated image filenames.
# Found 393 validated image filenames.
# 12/12 [==============================] - 5s 415ms/step - loss: -0.8996 - binary_accuracy: 0.9977 - iou: 0.8211 - dice_coef: 0.9010
# Test lost:  -0.899610698223114
# Test IOU:  0.9977099895477295
# Test Dice Coefficent:  0.8210766315460205

# %%
# Visualize the model results
for i in range(30):
    index=np.random.randint(1,len(df_test.index))
    img = cv2.imread(df_test['filename'].iloc[index])
    img = cv2.resize(img ,(im_height, im_width))
    img = img / 255
    img = img[np.newaxis, :, :, :]
    pred=model.predict(img)

    plt.figure(figsize=(12,12))
    plt.subplot(1,3,1)
    plt.imshow(np.squeeze(img))
    plt.title('Original Image')
    plt.subplot(1,3,2)
    plt.imshow(np.squeeze(cv2.imread(df_test['mask'].iloc[index])))
    plt.title('Original Mask')
    plt.subplot(1,3,3)
    plt.imshow(np.squeeze(pred) > .5)
    plt.title('Prediction')
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
